# %%
print("he")
# Out:
# he

# %%
import sys
# !{sys.executable} -m pip install sseclient
# Out:
# Collecting sseclient
#   Downloading https://files.pythonhosted.org/packages/ee/b9/baec6c72eb823161f60538c10a7d0a41d0144539b47ef388620b3ed50beb/sseclient-0.0.22.tar.gz
# Requirement already satisfied: requests>=2.0.0 in /home/nbuser/anaconda3_420/lib/python3.5/site-packages (from sseclient) (2.14.2)
# Requirement already satisfied: six in /home/nbuser/anaconda3_420/lib/python3.5/site-packages (from sseclient) (1.11.0)
# Building wheels for collected packages: sseclient
#   Building wheel for sseclient (setup.py) ... done
#   Stored in directory: /home/nbuser/.cache/pip/wheels/fc/b8/5c/c7e0a8161e61dc1ab00c0b5a1a34a3887eb47170ae1a46f7b1
# Successfully built sseclient
# Installing collected packages: sseclient
# Successfully installed sseclient-0.0.22

# %%
import json
from sseclient import SSEClient as EventSource

url = 'https://stream.wikimedia.org/v2/stream/recentchange'
count = 0
finaldocuments={}
documents=[]
for event in EventSource(url):
    if event.event == 'message':
        count = count + 1
        try:
            change = json.loads(event.data)
        except ValueError:
            pass
        else:
            print('{user} edited {title}'.format(**change))
            print(change)
            microdict={}
            microdict['language']= "en"
            microdict['text']=json.dumps(change)
            microdict['id']=count
            #print(microdict)
            documents.append(microdict)
            if count >10:
                break
finaldocuments['documents']=documents
# Out:
# Ferhad Kurdi edited kulafe
# {'user': 'Ferhad Kurdi', 'timestamp': 1551873036, 'type': 'edit', 'title': 'kulafe', 'length': {'new': 425, 'old': 436}, 'server_url': 'https://ku.wiktionary.org', 'parsedcomment': '<span dir="auto"><span class="autocomment"><a href="/wiki/kulafe#Wergerr" title="kulafe">→\u200eWergerr</a></span></span>', 'wiki': 'kuwiktionary', 'server_script_path': '/w', 'revision': {'new': 3045716, 'old': 3045715}, 'id': 3973909, 'meta': {'request_id': '17825028-8684-4d11-b5e0-3146df23cb7c', 'topic': 'eqiad.mediawiki.recentchange', 'uri': 'https://ku.wiktionary.org/wiki/kulafe', 'id': '0dfa544a-4006-11e9-8f84-b083fecf1287', 'partition': 0, 'domain': 'ku.wiktionary.org', 'schema_uri': 'mediawiki/recentchange/2', 'dt': '2019-03-06T11:50:36+00:00', 'offset': 1433302082}, 'server_name': 'ku.wiktionary.org', 'comment': '/* Wergerr */', 'minor': False, 'namespace': 0, 'bot': False}
# Tagishsimon edited Q45646044
# {'patrolled': True, 'user': 'Tagishsimon', 'timestamp': 1551873036, 'type': 'edit', 'title': 'Q45646044', 'length': {'new': 3473, 'old': 3381}, 'server_url': 'https://www.wikidata.org', 'parsedcomment': '\u200e<span dir="auto"><span class="autocomment">Added [en] description: </span></span> Ming dynasty person CBDB = 287465, #quickstatements; <a href="https://tools.wmflabs.org/quickstatements/#.2Fbatch.2F8923" class="extiw" title="toollabs:quickstatements/">batch #8923</a> by <a href="/wiki/User:Tagishsimon" title="User:Tagishsimon">User:Tagishsimon</a>', 'wiki': 'wikidatawiki', 'server_script_path': '/w', 'revision': {'new': 875580815, 'old': 860285316}, 'id': 912033162, 'meta': {'request_id': '48880213-45d1-4a7d-bfd0-98d248aa1853', 'topic': 'eqiad.mediawiki.recentchange', 'uri': 'https://www.wikidata.org/wiki/Q45646044', 'id': '0dfa5557-4006-11e9-b38a-141877614a81', 'partition': 0, 'domain': 'www.wikidata.org', 'schema_uri': 'mediawiki/recentchange/2', 'dt': '2019-03-06T11:50:36+00:00', 'offset': 1433302083}, 'server_name': 'www.wikidata.org', 'comment': '/* wbsetdescription-add:1|en */ Ming dynasty person CBDB = 287465, #quickstatements; [[:toollabs:quickstatements/#/batch/8923|batch #8923]] by [[User:Tagishsimon|]]', 'minor': False, 'namespace': 0, 'bot': False}
# Renamerr edited Q34482634
# {'patrolled': True, 'user': 'Renamerr', 'timestamp': 1551873035, 'type': 'edit', 'title': 'Q34482634', 'length': {'new': 330899, 'old': 330852}, 'server_url': 'https://www.wikidata.org', 'parsedcomment': '\u200e<span dir="auto"><span class="autocomment">Змінено опис [uk]: </span></span> наукова стаття, опублікована в червні 2015, #quickstatements', 'wiki': 'wikidatawiki', 'server_script_path': '/w', 'revision': {'new': 875580814, 'old': 763735689}, 'id': 912033163, 'meta': {'request_id': 'f1fbd5d4-120e-42ae-aceb-3ce6da81740a', 'topic': 'eqiad.mediawiki.recentchange', 'uri': 'https://www.wikidata.org/wiki/Q34482634', 'id': '0dfa6127-4006-11e9-84ae-b083fecf0db3', 'partition': 0, 'domain': 'www.wikidata.org', 'schema_uri': 'mediawiki/recentchange/2', 'dt': '2019-03-06T11:50:35+00:00', 'offset': 1433302084}, 'server_name': 'www.wikidata.org', 'comment': '/* wbsetdescription-set:1|uk */ наукова стаття, опублікована в червні 2015, #quickstatements', 'minor': False, 'namespace': 0, 'bot': True}
# Drewes edited Kategory:Gritenijsekretaris
# {'user': 'Drewes', 'timestamp': 1551873035, 'type': 'categorize', 'title': 'Kategory:Gritenijsekretaris', 'server_url': 'https://fy.wikipedia.org', 'parsedcomment': '<a href="/wiki/Bernhard_Munniks" title="Bernhard Munniks">Bernhard Munniks</a> added to category', 'wiki': 'fywiki', 'server_script_path': '/w', 'id': 2707223, 'meta': {'request_id': 'XH@0CwpAICoAAAVZz8gAAAAS', 'topic': 'eqiad.mediawiki.recentchange', 'uri': 'https://fy.wikipedia.org/wiki/Kategory:Gritenijsekretaris', 'id': '0dfa5474-4006-11e9-9632-1418776149df', 'partition': 0, 'domain': 'fy.wikipedia.org', 'schema_uri': 'mediawiki/recentchange/2', 'dt': '2019-03-06T11:50:35+00:00', 'offset': 1433302085}, 'server_name': 'fy.wikipedia.org', 'comment': '[[:Bernhard Munniks]] added to category', 'namespace': 14, 'bot': False}
# Drewes edited Kategory:Frysk persoan fan Dútsk komôf
# {'user': 'Drewes', 'timestamp': 1551873035, 'type': 'categorize', 'title': 'Kategory:Frysk persoan fan Dútsk komôf', 'server_url': 'https://fy.wikipedia.org', 'parsedcomment': '<a href="/wiki/Bernhard_Munniks" title="Bernhard Munniks">Bernhard Munniks</a> added to category', 'wiki': 'fywiki', 'server_script_path': '/w', 'id': 2707224, 'meta': {'request_id': 'XH@0CwpAICoAAAVZz8gAAAAS', 'topic': 'eqiad.mediawiki.recentchange', 'uri': 'https://fy.wikipedia.org/wiki/Kategory:Frysk_persoan_fan_D%C3%BAtsk_kom%C3%B4f', 'id': '0dfa5475-4006-11e9-9632-1418776149df', 'partition': 0, 'domain': 'fy.wikipedia.org', 'schema_uri': 'mediawiki/recentchange/2', 'dt': '2019-03-06T11:50:35+00:00', 'offset': 1433302086}, 'server_name': 'fy.wikipedia.org', 'comment': '[[:Bernhard Munniks]] added to category', 'namespace': 14, 'bot': False}
# Drewes edited Kategory:Persoan berne op De Jouwer
# {'user': 'Drewes', 'timestamp': 1551873035, 'type': 'categorize', 'title': 'Kategory:Persoan berne op De Jouwer', 'server_url': 'https://fy.wikipedia.org', 'parsedcomment': '<a href="/wiki/Bernhard_Munniks" title="Bernhard Munniks">Bernhard Munniks</a> removed from category', 'wiki': 'fywiki', 'server_script_path': '/w', 'id': 2707225, 'meta': {'request_id': 'XH@0CwpAICoAAAVZz8gAAAAS', 'topic': 'eqiad.mediawiki.recentchange', 'uri': 'https://fy.wikipedia.org/wiki/Kategory:Persoan_berne_op_De_Jouwer', 'id': '0dfa5476-4006-11e9-9632-1418776149df', 'partition': 0, 'domain': 'fy.wikipedia.org', 'schema_uri': 'mediawiki/recentchange/2', 'dt': '2019-03-06T11:50:35+00:00', 'offset': 1433302087}, 'server_name': 'fy.wikipedia.org', 'comment': '[[:Bernhard Munniks]] removed from category', 'namespace': 14, 'bot': False}
# Раммон edited Oracle Database
# {'log_action_comment': 'Раммон отпатрулировал версию страницы [[Oracle Database]]: [Состояние: отпатрулирована]', 'log_params': [98488056, 98058592, '20190306111645'], 'type': 'log', 'title': 'Oracle Database', 'user': 'Раммон', 'server_url': 'https://ru.wikipedia.org', 'comment': '[Состояние: отпатрулирована]', 'parsedcomment': '[Состояние: отпатрулирована]', 'wiki': 'ruwiki', 'server_script_path': '/w', 'timestamp': 1551873036, 'meta': {'request_id': '463c5406-0166-43ef-a744-bcae187c5bd4', 'topic': 'eqiad.mediawiki.recentchange', 'uri': 'https://ru.wikipedia.org/wiki/Oracle_Database', 'id': '0e92f255-4006-11e9-a1eb-b083fecefa7f', 'partition': 0, 'domain': 'ru.wikipedia.org', 'schema_uri': 'mediawiki/recentchange/2', 'dt': '2019-03-06T11:50:36+00:00', 'offset': 1433302088}, 'log_id': 65744776, 'log_action': 'approve', 'server_name': 'ru.wikipedia.org', 'log_type': 'review', 'namespace': 0, 'bot': False}
# MRewald edited Q1497451
# {'patrolled': True, 'user': 'MRewald', 'timestamp': 1551873036, 'type': 'edit', 'title': 'Q1497451', 'length': {'new': 7253, 'old': 7178}, 'server_url': 'https://www.wikidata.org', 'parsedcomment': '\u200e<span dir="auto"><span class="autocomment">Beschreibung für [de] hinzugefügt: </span></span> IT-Dienstleister', 'wiki': 'wikidatawiki', 'server_script_path': '/w', 'revision': {'new': 875580817, 'old': 808483998}, 'id': 912033164, 'meta': {'request_id': '04bf8758-8ebe-4fc8-9742-cda02c8e9c84', 'topic': 'eqiad.mediawiki.recentchange', 'uri': 'https://www.wikidata.org/wiki/Q1497451', 'id': '0e92f785-4006-11e9-b51c-1418776141b3', 'partition': 0, 'domain': 'www.wikidata.org', 'schema_uri': 'mediawiki/recentchange/2', 'dt': '2019-03-06T11:50:36+00:00', 'offset': 1433302089}, 'server_name': 'www.wikidata.org', 'comment': '/* wbsetdescription-add:1|de */ IT-Dienstleister', 'minor': False, 'namespace': 0, 'bot': False}
# 円周率３パーセント edited Category:Media with locations
# {'user': '円周率３パーセント', 'timestamp': 1551873035, 'type': 'categorize', 'title': 'Category:Media with locations', 'server_url': 'https://commons.wikimedia.org', 'parsedcomment': '<a href="/wiki/File:Ogama_Park_20190306-04.jpg" title="File:Ogama Park 20190306-04.jpg">File:Ogama Park 20190306-04.jpg</a> added to category', 'wiki': 'commonswiki', 'server_script_path': '/w', 'id': 1196036128, 'meta': {'request_id': 'XH@0CApAAEcAAJWBDOQAAAAU', 'topic': 'eqiad.mediawiki.recentchange', 'uri': 'https://commons.wikimedia.org/wiki/Category:Media_with_locations', 'id': '0dfa4fde-4006-11e9-b15c-1866da994d3b', 'partition': 0, 'domain': 'commons.wikimedia.org', 'schema_uri': 'mediawiki/recentchange/2', 'dt': '2019-03-06T11:50:35+00:00', 'offset': 1433302090}, 'server_name': 'commons.wikimedia.org', 'comment': '[[:File:Ogama Park 20190306-04.jpg]] added to category', 'namespace': 14, 'bot': False}
# 円周率３パーセント edited Category:CC-BY-SA-4.0
# {'user': '円周率３パーセント', 'timestamp': 1551873035, 'type': 'categorize', 'title': 'Category:CC-BY-SA-4.0', 'server_url': 'https://commons.wikimedia.org', 'parsedcomment': '<a href="/wiki/File:Ogama_Park_20190306-04.jpg" title="File:Ogama Park 20190306-04.jpg">File:Ogama Park 20190306-04.jpg</a> added to category', 'wiki': 'commonswiki', 'server_script_path': '/w', 'id': 1196036129, 'meta': {'request_id': 'XH@0CApAAEcAAJWBDOQAAAAU', 'topic': 'eqiad.mediawiki.recentchange', 'uri': 'https://commons.wikimedia.org/wiki/Category:CC-BY-SA-4.0', 'id': '0dfa4fdf-4006-11e9-b15c-1866da994d3b', 'partition': 0, 'domain': 'commons.wikimedia.org', 'schema_uri': 'mediawiki/recentchange/2', 'dt': '2019-03-06T11:50:35+00:00', 'offset': 1433302091}, 'server_name': 'commons.wikimedia.org', 'comment': '[[:File:Ogama Park 20190306-04.jpg]] added to category', 'namespace': 14, 'bot': False}

# %%
print(finaldocuments)
# Out:
# {'documents': [{'language': 'en', 'id': 2, 'text': '{"user": "Ferhad Kurdi", "timestamp": 1551873036, "type": "edit", "title": "kulafe", "length": {"new": 425, "old": 436}, "server_url": "https://ku.wiktionary.org", "parsedcomment": "<span dir=\\"auto\\"><span class=\\"autocomment\\"><a href=\\"/wiki/kulafe#Wergerr\\" title=\\"kulafe\\">\\u2192\\u200eWergerr</a></span></span>", "wiki": "kuwiktionary", "server_script_path": "/w", "revision": {"new": 3045716, "old": 3045715}, "id": 3973909, "meta": {"request_id": "17825028-8684-4d11-b5e0-3146df23cb7c", "topic": "eqiad.mediawiki.recentchange", "uri": "https://ku.wiktionary.org/wiki/kulafe", "id": "0dfa544a-4006-11e9-8f84-b083fecf1287", "partition": 0, "domain": "ku.wiktionary.org", "schema_uri": "mediawiki/recentchange/2", "dt": "2019-03-06T11:50:36+00:00", "offset": 1433302082}, "server_name": "ku.wiktionary.org", "comment": "/* Wergerr */", "minor": false, "namespace": 0, "bot": false}'}, {'language': 'en', 'id': 3, 'text': '{"patrolled": true, "user": "Tagishsimon", "timestamp": 1551873036, "type": "edit", "title": "Q45646044", "length": {"new": 3473, "old": 3381}, "server_url": "https://www.wikidata.org", "parsedcomment": "\\u200e<span dir=\\"auto\\"><span class=\\"autocomment\\">Added [en] description: </span></span> Ming dynasty person CBDB = 287465, #quickstatements; <a href=\\"https://tools.wmflabs.org/quickstatements/#.2Fbatch.2F8923\\" class=\\"extiw\\" title=\\"toollabs:quickstatements/\\">batch #8923</a> by <a href=\\"/wiki/User:Tagishsimon\\" title=\\"User:Tagishsimon\\">User:Tagishsimon</a>", "wiki": "wikidatawiki", "server_script_path": "/w", "revision": {"new": 875580815, "old": 860285316}, "id": 912033162, "meta": {"request_id": "48880213-45d1-4a7d-bfd0-98d248aa1853", "topic": "eqiad.mediawiki.recentchange", "uri": "https://www.wikidata.org/wiki/Q45646044", "id": "0dfa5557-4006-11e9-b38a-141877614a81", "partition": 0, "domain": "www.wikidata.org", "schema_uri": "mediawiki/recentchange/2", "dt": "2019-03-06T11:50:36+00:00", "offset": 1433302083}, "server_name": "www.wikidata.org", "comment": "/* wbsetdescription-add:1|en */ Ming dynasty person CBDB = 287465, #quickstatements; [[:toollabs:quickstatements/#/batch/8923|batch #8923]] by [[User:Tagishsimon|]]", "minor": false, "namespace": 0, "bot": false}'}, {'language': 'en', 'id': 4, 'text': '{"patrolled": true, "user": "Renamerr", "timestamp": 1551873035, "type": "edit", "title": "Q34482634", "length": {"new": 330899, "old": 330852}, "server_url": "https://www.wikidata.org", "parsedcomment": "\\u200e<span dir=\\"auto\\"><span class=\\"autocomment\\">\\u0417\\u043c\\u0456\\u043d\\u0435\\u043d\\u043e \\u043e\\u043f\\u0438\\u0441 [uk]: </span></span> \\u043d\\u0430\\u0443\\u043a\\u043e\\u0432\\u0430 \\u0441\\u0442\\u0430\\u0442\\u0442\\u044f, \\u043e\\u043f\\u0443\\u0431\\u043b\\u0456\\u043a\\u043e\\u0432\\u0430\\u043d\\u0430 \\u0432 \\u0447\\u0435\\u0440\\u0432\\u043d\\u0456 2015, #quickstatements", "wiki": "wikidatawiki", "server_script_path": "/w", "revision": {"new": 875580814, "old": 763735689}, "id": 912033163, "meta": {"request_id": "f1fbd5d4-120e-42ae-aceb-3ce6da81740a", "topic": "eqiad.mediawiki.recentchange", "uri": "https://www.wikidata.org/wiki/Q34482634", "id": "0dfa6127-4006-11e9-84ae-b083fecf0db3", "partition": 0, "domain": "www.wikidata.org", "schema_uri": "mediawiki/recentchange/2", "dt": "2019-03-06T11:50:35+00:00", "offset": 1433302084}, "server_name": "www.wikidata.org", "comment": "/* wbsetdescription-set:1|uk */ \\u043d\\u0430\\u0443\\u043a\\u043e\\u0432\\u0430 \\u0441\\u0442\\u0430\\u0442\\u0442\\u044f, \\u043e\\u043f\\u0443\\u0431\\u043b\\u0456\\u043a\\u043e\\u0432\\u0430\\u043d\\u0430 \\u0432 \\u0447\\u0435\\u0440\\u0432\\u043d\\u0456 2015, #quickstatements", "minor": false, "namespace": 0, "bot": true}'}, {'language': 'en', 'id': 5, 'text': '{"user": "Drewes", "timestamp": 1551873035, "type": "categorize", "title": "Kategory:Gritenijsekretaris", "server_url": "https://fy.wikipedia.org", "pars ...

# %%
subscription_key = "3d80e125aeba44739c7d9b62c9c02c30"
assert subscription_key
text_analytics_base_url = "https://westeurope.api.cognitive.microsoft.com/text/analytics/v2.1-preview/entities"

# %%
import requests
from pprint import pprint
headers   = {"Ocp-Apim-Subscription-Key": subscription_key}
response  = requests.post(text_analytics_base_url, headers=headers, json=finaldocuments)
entitities = response.json()
pprint(entitities['documents'][0])
# Out:
# {'entities': [{'matches': [{'length': 10, 'offset': 38, 'text': '1551873036'}],
#                'name': '1551873036',
#                'subType': 'Number',
#                'type': 'Quantity'},
#               {'matches': [{'length': 3, 'offset': 103, 'text': '425'}],
#                'name': '425',
#                'subType': 'Number',
#                'type': 'Quantity'},
#               {'matches': [{'length': 3, 'offset': 115, 'text': '436'}],
#                'name': '436',
#                'subType': 'Number',
#                'type': 'Quantity'},
#               {'matches': [{'length': 25,
#                             'offset': 136,
#                             'text': 'https://ku.wiktionary.org'}],
#                'name': 'https://ku.wiktionary.org',
#                'type': 'URL'},
#               {'matches': [{'length': 7, 'offset': 381, 'text': '3045716'}],
#                'name': '3045716',
#                'subType': 'Number',
#                'type': 'Quantity'},
#               {'matches': [{'length': 7, 'offset': 397, 'text': '3045715'}],
#                'name': '3045715',
#                'subType': 'Number',
#                'type': 'Quantity'},
#               {'matches': [{'length': 7, 'offset': 413, 'text': '3973909'}],
#                'name': '3973909',
#                'subType': 'Number',
#                'type': 'Quantity'},
#               {'matches': [{'length': 8, 'offset': 446, 'text': '17825028'}],
#                'name': '17825028',
#                'subType': 'Number',
#                'type': 'Quantity'},
#               {'matches': [{'length': 4, 'offset': 455, 'text': '8684'}],
#                'name': '8684',
#                'subType': 'Number',
#                'type': 'Quantity'},
#               {'matches': [{'length': 37,
#                             'offset': 534,
#                             'text': 'https://ku.wiktionary.org/wiki/kulafe'}],
#                'name': 'https://ku.wiktionary.org/wiki/kulafe',
#                'type': 'URL'},
#               {'matches': [{'length': 5, 'offset': 589, 'text': '-4006'}],
#                'name': '-4006',
#                'subType': 'Number',
#                'type': 'Quantity'},
#               {'matches': [{'length': 4, 'offset': 595, 'text': '11e9'}],
#                'name': '11e9',
#                'subType': 'Number',
#                'type': 'Quantity'},
#               {'matches': [{'length': 2, 'offset': 600, 'text': '8f'}],
#                'name': '8f',
#                'subType': 'Temperature',
#                'type': 'Quantity'},
#               {'matches': [{'length': 1, 'offset': 633, 'text': '0'},
#                            {'length': 1, 'offset': 860, 'text': '0'}],
#                'name': '0',
#                'subType': 'Number',
#                'type': 'Quantity'},
#               {'matches': [{'length': 17,
#                             'offset': 647,
#                             'text': 'ku.wiktionary.org'},
#                            {'length': 17,
#                             'offset': 783,
#                             'text': 'ku.wiktionary.org'}],
#                'name': 'ku.wiktionary.org',
#                'type': 'URL'},
#               {'matches': [{'length': 3, 'offset': 675, 'text': 'uri'}],
#                'name': 'uri',
#                'type': 'Location'},
#               {'matches': [{'length': 2, 'offset': 705, 'text': '2"'}],
#                'name': '2"',
#                'subType': 'Dimension',
#                'type': 'Quantity'},
#               {'matches': [{'length': 19,
#                             'offset': 716,
#                             'text': '2019-03-06T11:50:36'}],
#                'name': '2019-03-06T11:50:36',
#                'type': 'DateTime'},
#               {'matches': [{'length': 5, 'offset': 736, 'text': '00:00'}],
#                'name': '00:00',
#                'subType': 'Time',
#                'type': 'DateTime'},
#               {'matches': [{'length': 3, 'offset': 739, 'text': '00"'}],
#                'name': '00"',
#                'subType': 'Dimension',
#                'type': 'Quantity'},
#               {'matches': [{'length': 10, 'offset': 754, 'text': '1433302082'}],
#                'name': '1433302082',
#                'subType': 'Number',
#                'type': 'Quantity'},
#               {'matches': [{'length': 3, 'offset': 864, 'text': 'bot'}],
#                'name': 'bot',
#                'type': 'Location'}],
#  'id': '2'}

# %%
from requests import get
from requests.exceptions import RequestException
from contextlib import closing
from bs4 import BeautifulSoup


def simple_get(url):
    try:
        with closing(get(url, stream=True)) as resp:
            if is_good_response(resp):
                return resp.content
            else:
                return None

    except RequestException as e:
        log_error('Error during requests to {0} : {1}'.format(url, str(e)))
        return None


def is_good_response(resp):
    content_type = resp.headers['Content-Type'].lower()
    return (resp.status_code == 200 
            and content_type is not None 
            and content_type.find('html') > -1)


def log_error(e):
    print(e)

# %%
def scrapindeed(urlservices):
  total=[]
  raw_html = simple_get(urlservices)
  myhtml = BeautifulSoup(raw_html, 'html.parser')
  tabulka = myhtml.findAll("div",  {"class" : "cmp-review-container"})
  for container in tabulka:
      partial=[]
      tittle = container.find("div",  {"class" : "cmp-review-title"})
      tittle = tittle.text
      partial.append(tittle)
      subtittle = container.find("div",  {"class" : "cmp-review-subtitle"})
      subtittle = subtittle.text
      partial.append(subtittle)
      freetext = container.find("span",  {"class" : "cmp-review-text"})
      myfreetext = freetext.text
      partial.append(myfreetext)
      protext = container.find("div",  {"class" : "cmp-review-pro-text"})
      if protext is not None:
          protext = protext.text
      else:
          protext=""
      partial.append(protext)
      constext = container.find("div",  {"class" : "cmp-review-con-text"})
      if constext is not None:
          constext= constext.text
      else:
          constext=""
      partial.append(constext)
      total.append(partial)
      print("#########")
  return(total)

# %%
urlservices= "https://www.indeed.co.uk/cmp/Microsoft/reviews?fcountry=ALL"
total =scrapindeed(urlservices)
# Out:
# #########
# #########
# #########
# #########
# #########
# #########
# #########
# #########
# #########
# #########
# #########
# #########
# #########
# #########
# #########
# #########
# #########
# #########
# #########
# #########
# #########

# %%
print(total[0][2])
# Out:
# Good culture & great flexibility. Can be a little hard to get promotions and forward career.Company definitely changed over etc years, less autonomy at a local level and more direction form corporate.

# %%
count=0
count = 0
finaldocuments={}
documents=[]
for doc in total:
    count = count + 1
    microdict={}
    microdict['language']= "en"
    microdict['text']=doc[2]
    microdict['id']=count
            #print(microdict)
    documents.append(microdict)

finaldocuments['documents']=documents

# %%
print(json.dumps(finaldocuments,indent=1))
# Out:
# {
#  "documents": [
#   {
#    "language": "en",
#    "id": 1,
#    "text": "Good culture & great flexibility. Can be a little hard to get promotions and forward career.Company definitely changed over etc years, less autonomy at a local level and more direction form corporate."
#   },
#   {
#    "language": "en",
#    "id": 2,
#    "text": "So much to do and so little time. Microsoft was just getting into marketing when I started working with the team. The approach was right and the new tech being released now is great."
#   },
#   {
#    "language": "en",
#    "id": 3,
#    "text": "Fun environment, the workplace and management helped you to learn a lot. A typical day at work was filled with engaging with the industry experts from all over the world."
#   },
#   {
#    "language": "en",
#    "id": 4,
#    "text": "It was an electric experience.  Always new products and services.  The store is nice and bright.  Overall a fun environment.  Smart people.  Very Diverse."
#   },
#   {
#    "language": "en",
#    "id": 5,
#    "text": "I have worked at Microsoft, Redmond from 2001 to 2012 and then at Microsoft, India from 2012 - 2016. Microsoft is the best company I have worked at, with numerous growth opportunities, transparent culture. The only drawback is continuous reorgs."
#   },
#   {
#    "language": "en",
#    "id": 6,
#    "text": "Possibilit\u00e9 d'\u00e9voluer sur des postes \u00e0 plus large p\u00e9rim\u00e8tre."
#   },
#   {
#    "language": "en",
#    "id": 7,
#    "text": "Everyday is a new day or challenges and learning from others and different customer needs and feedback!Always an education dayGreat people!Love it!Thank you"
#   },
#   {
#    "language": "en",
#    "id": 8,
#    "text": "Fun place to work and the co-workers are so much fun. However, management refuses to promote people who are successful and seem to only care about advancing their own careers."
#   },
#   {
#    "language": "en",
#    "id": 9,
#    "text": "Working for Microsoft is really good.  Extremely good workplace culture where you can grow your skills and seek help when ever needed. Great company to work with."
#   },
#   {
#    "language": "en",
#    "id": 10,
#    "text": "Microsoft feels like a family & was a truly enjoyable place to work. My time there was some my most memorable. Outside of the Military I've never had  quite an experience at a work place."
#   },
#   {
#    "language": "en",
#    "id": 11,
#    "text": "A smart business model with embedded software in billions of PCs ensures Microsoft's growth and survival, very smart people but extremely political and a backstabbing cultural environment. People get paid well. Management doesn't like bad news or numbers so all reports are sugar coated and true issues are hidden, no one wants to look bad and be accountable for mistakes, no matter the level of the screw ups the company will endure, sort of like \"putting the dust under the carpet\". A great career experience. Microsoft has designed break thru technologies but somehow can't manage to scale and launch successfully, trailing behind others, again it's core is in the Enterprise and is very successful in that space. Couldn't be more grateful for the things I learned at MS, the people I met and the opportunities I received, but it's a miserable place to be at, you are there for the paycheck and waiting for the quarterly sledgehammer to come down, either you move up or you move out, but sooner or later everyone goes."
#   },
#   {
#    "language": "en",
#    "id": 12,
#    "text": "It was very open and relaxed place to work.  It was not micro managed but there was a different way contractors were treated versus full time employees."
#   },
#   {
#    "language": "en",
#    "id": 13,
#    "text": "Working with a team to sell microsoft product and build loyalty to the brand. Could have been a good environment but the management was not effective at the location i was employed."
#   },
#   {
#    "language": "en",
#    "id": 14,
#    "text": "Uma das melhores empresas que j\u00e1 trabalhei na minha vida"
#   },
#   {
#    "language": "en",
#    "id": 15,
#    "text": "Microsoft is a dream gig to land, so of course it's great to have on your resume. They promise you opportunity to advance, which is true, but they also promise you a balance of family and work life which is false. The HR department is a JOKE and favoritism is HIGH, at least when I was working there."
#   },
#   {
#    "language": "en",
#    "id": 16,
#    "text": "Microsoft deserves its reputation as an excellent workplace. The supportive environment, exciting opportunities, and fellow employees are the best aspects to working there."
#   },
#   {
#    "language": "en",
#    "id": 17,
#    "text": "Good place to work, good benefits, team/fit matter. Plenty of opportunities to develop within a specific focus area or to learn new products, skills, or industries."
#   },
#   {
#    "language": "en",
#    "id": 18,
#    "text": "I worked on multiple project in HCL and part of project I am able to work on different companies and learn lot.Learn new technologies DC migration .Work culture .Making customer happy was our main motivation .Able to provide new value added idea to customer.Made operation hygiene.Worked on multiple automation which make my team mate life easy."
#   },
#   {
#    "language": "en",
#    "id": 19,
#    "text": "Amazing experience when working in as a placement year student. The role was unique, challenging and focused on development, allowing me to put what I'd learnt at University into action."
#   },
#   {
#    "language": "en",
#    "id": 20,
#    "text": "The company has a lot of great energy, and passion and that synergy is certainly passed on to the employees. but when you want to grow, things can get a little tricky. Also be careful of some of the roles you end up in. they may not promise you full time hours and cut your hours without notice. depending on the manager, they may not be too welcoming to talk about it and efforts within the company to resolve things, may not always go as desired."
#   },
#   {
#    "language": "en",
#    "id": 21,
#    "text": "i was happy with microsoft. they only problem was my job was temp and not full time. I had my best time there at portland location. the culture inside is great."
#   }
#  ]
# }

# %%
    
subscription_key = "3d80e125aeba44739c7d9b62c9c02c30"
assert subscription_key
text_analytics_base_url = "https://westeurope.api.cognitive.microsoft.com/text/analytics/v2.0/sentiment"

# %%
headers   = {"Ocp-Apim-Subscription-Key": subscription_key}
response  = requests.post(text_analytics_base_url, headers=headers, json=finaldocuments)
sentiments = response.json()
pprint(sentiments['documents'])
# Out:
# [{'id': '1', 'score': 0.24263864755630493},
#  {'id': '2', 'score': 0.8565806150436401},
#  {'id': '3', 'score': 0.8818988800048828},
#  {'id': '4', 'score': 0.9837856292724609},
#  {'id': '5', 'score': 0.9107358455657959},
#  {'id': '6', 'score': 0.5},
#  {'id': '7', 'score': 0.9687870740890503},
#  {'id': '8', 'score': 0.802191972732544},
#  {'id': '9', 'score': 0.9708796739578247},
#  {'id': '10', 'score': 0.8216674327850342},
#  {'id': '11', 'score': 0.19738838076591492},
#  {'id': '12', 'score': 0.8171086311340332},
#  {'id': '13', 'score': 0.2197723090648651},
#  {'id': '14', 'score': 0.7562829852104187},
#  {'id': '15', 'score': 0.8811904788017273},
#  {'id': '16', 'score': 0.9924623966217041},
#  {'id': '17', 'score': 0.9490007162094116},
#  {'id': '18', 'score': 0.9566161036491394},
#  {'id': '19', 'score': 0.8037079572677612},
#  {'id': '20', 'score': 0.23848691582679749},
#  {'id': '21', 'score': 0.8745341300964355}]
